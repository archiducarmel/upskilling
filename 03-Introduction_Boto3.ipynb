# %% [markdown]
# ![ai](https://www.emineo-education.fr/wp-content/uploads/2022/11/supdevinci-nantes.png)
#
#
# <h4 style="text-align: left; color:#20a08d; font-size: 35px"><span><strong> AWS : Introduction à Boto3</strong></span></h4>

# %% [markdown]
# <h4 style="text-align: left; color:#20a08d; font-size: 25px"><span><strong> Ce que vous apprendrez dans ce cours 🧐🧐</strong></span></h4>
#
# Comme nous commençons à couvrir de nombreux services AWS différents, vous devez y accéder par programmation au lieu de toujours utiliser l'interface utilisateur graphique.
#
# C'est la raison d'être de Boto3. Dans ce cours, nous aborderons :
#
# - Utiliser Boto3 pour accéder à n'importe quel service AWS
# - Intégrer vos informations d'identification AWS pour accéder à votre compte AWS

# %% [markdown]
# <h4 style="text-align: left; color:#20a08d; font-size: 25px"><span><strong> Qu'est-ce que Boto3 ? 🤔🤔</strong></span></h4>

# %% [markdown]
# Boto3 est le SDK d'AWS. Il vous permettra d'accéder par programme à votre compte et à vos services AWS. Ceci est particulièrement utile lorsque vous devez créer une application Web ou créer des processus.

# %% [markdown]
# <div class="alert alert-info">
#   <strong>🙋 C'est quoi un SDK ?! 🙋
# </strong><br> SDK signifie "Software Development Kit" ("Kit de développement logiciel"). Il s'agit essentiellement d'un kit qui fournit un ensemble d'outils, de bibliothèques et de documentation pour vous aider à utiliser le service de quelqu'un.
#
# </div>

# %% [markdown]
# Commençons à installer boto3

# %%
# !pip3 install Boto3
#ACCESS_KEY=AKIAQ3EGWN4BJHO4WN5I
#SECRET_KEY=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
# Out:
# ...
# WARNING: You are using pip version 22.0.4; however, version 25.0 is available.
# You should consider upgrading via the 'C:\Users\Sitou\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.
# ...

# %% [markdown]
# <h4 style="text-align: left; color:#20a08d; font-size: 25px"><span><strong> Commandes de base de Boto3 🧭🧭</strong></span></h4>

# %% [markdown]
# Vous utiliserez beaucoup Boto3 tout au long de vos projets.
#
# Vous verrez que ce SDK est assez simple à utiliser. Cependant, Boto3 vous permet d'utiliser **N'IMPORTE QUEL service** dont vous avez besoin dans AWS.
#
# Par conséquent, nous n'allons certainement pas couvrir tous les services que Boto3 vous permet d'utiliser. Au lieu de cela, nous vous apprendrons à utiliser les bases de Boto3 et vous apprendrons à consulter la documentation.

# %% [markdown]
# <h4 style="text-align: left; color:#20a08d; font-size: 20px"><span><strong> Documentation</strong></span></h4>

# %% [markdown]
# Votre meilleur ami lorsque vous utilisez Boto3 est **la documentation 📜**! Par conséquent, voici le lien pour la <a href="https://boto3.amazonaws.com/v1/documentation/api/latest/guide/quickstart.html" target="_blank">documentation Boto3</a>. .
#
# La documentation vous montrera comment installer Boto3 sur votre ordinateur mais vous donnera également un tutoriel de démarrage rapide sur la façon de l'utiliser.
#
# Il y a deux choses principales que vous devez savoir sur la documentation :
#
# - <a href="https://boto3.amazonaws.com/v1/documentation/api/latest/guide/quickstart.html" target="_blank">Démarrage rapide</a> : il va vous permettre d'être opérationnel sur Boto3.
# - <a href="https://boto3.amazonaws.com/v1/documentation/api/latest/reference/services/index.html" target="_blank">Services disponibles</a> : va vous lister tous les différents services AWS auxquels vous pouvez accéder en utilisant Boto3. Une fois que vous avez choisi le service que vous souhaitez utiliser, vous pouvez vérifier toutes les fonctions disponibles que vous pouvez utiliser.

# %% [markdown]
# <h4 style="text-align: left; color:#20a08d; font-size: 20px"><span><strong> Sélectionnez une ressource</strong></span></h4>

# %% [markdown]
# La première chose que vous devez faire lorsque vous utilisez Boto3 est de configurer une session et d'utiliser une ressource donnée. Vous pouvez configurer une session à l'aide de `boto3.Session()`.

# %%
import boto3

# %% [markdown]
# Vous devez spécifier votre propre identifiant de clé d'accès et votre clé d'accès secrète que vous avez téléchargés lorsque vous avez créé votre utilisateur IAM. Si vous avez oublié ou perdu ou même jamais créé vos identifiants, vous pouvez toujours effectuer les opérations suivantes :

# %% [markdown]
# Activez la commande **"Security Credentials"** dans la section de votre compte en haut en droite de l'écran d'accueil AWS

# %% [markdown]
# ![S3](https://github.com/archiducarmel/SupDeVinci_Developpement/releases/download/ia_ml_aws/Selection_173.png)

# %% [markdown]
# Dans la section "Access keys", sélectionnez "Create access key" pour créer vos clés d'accès à AWS

# %% [markdown]
# ![S3](https://github.com/archiducarmel/SupDeVinci_Developpement/releases/download/ia_ml_aws/Selection_174.png)

# %% [markdown]
# Sélectionner dans la liste proposée **"Local code"** qui correspond à une utilisation de clé dans une application locale, puis "Next"

# %% [markdown]
# ![S3](https://github.com/archiducarmel/SupDeVinci_Developpement/releases/download/ia_ml_aws/Selection_175.png)

# %% [markdown]
# Créer un tag associé aux clés créés

# %% [markdown]
# ![S3](https://github.com/archiducarmel/SupDeVinci_Developpement/releases/download/ia_ml_aws/Selection_176.png)

# %% [markdown]
# Vos clés sont prêtes : **access key et secret key**. Cliquez sur "Show" pour afficher la "Secret Key".

# %% [markdown]
# ![S3](https://github.com/archiducarmel/SupDeVinci_Developpement/releases/download/ia_ml_aws/Selection_177.png)

# %% [markdown]
# <div class="alert alert-danger">
#   <strong>⚠ ATTENTION !</strong><br> Pensez à télécharger vos clés au format CSV pour utilisation ultérieure</div>

# %% [markdown]
# Les accès sont créés. Commençons à les utiliser avec boto3

# %%
# !pip3 install python-dotenv
# Out:
# ...
# WARNING: You are using pip version 22.0.4; however, version 25.0 is available.
# You should consider upgrading via the 'C:\Users\Sitou\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
from dotenv import load_dotenv
import os
load_dotenv()  # take environment variables from .env.
# Out:
# True

# %%
session = boto3.Session(aws_access_key_id=os.getenv("ACCESS_KEY"), aws_secret_access_key=os.getenv("SECRET_KEY"))

# %% [markdown]
# Maintenant que votre session est créée avec les bonnes informations d'identification, vous pouvez configurer une ressource. Prenons S3 par exemple :

# %%
s3 = session.resource("s3")

# %% [markdown]
# Vous pouvez maintenant utiliser toutes les actions disponibles que boto3 vous permettra de faire

# %%
bucket = s3.create_bucket(Bucket="bucket-from-notebook-sdv2025")

# %% [markdown]
# Si vous souhaitez en savoir plus sur cette fonction 👉 consultez <a href="https://boto3.amazonaws.com/v1/documentation/api/latest/reference/services/s3.html#S3.ServiceResource.create_bucket" target="_blank">create_bucket</a>

# %% [markdown]
# <h4 style="text-align: left; color:#20a08d; font-size: 20px"><span><strong> Charger un dataframe dans le bucket s3</strong></span></h4>

# %% [markdown]
# Voici un exemple de chargement d'un dataframe .csv dans votre bucket :

# %%
# !pip3 install pandas

# %%
import pandas as pd
data = pd.DataFrame({'col1': [1,2,3,4], 'col2': ['a1','a2','a3','a4']})
data.head()
# Out:
#    col1 col2
# 0     1   a1
# 1     2   a2
# 2     3   a3
# 3     4   a4

# %%
csv_content = data.to_csv()

# %%
put_object = bucket.put_object(Key="test.csv", Body=csv_content)

# %% [markdown]
# De nombreuses méthodes différentes sont disponibles pour uploader, télécharger et autres fonctionnalités, vous pouvez toutes les trouver [ici](https://boto3.amazonaws.com/v1/documentation/api/latest/reference/services/s3.html).

# %% [markdown]
# <h4 style="text-align: left; color:#20a08d; font-size: 25px"><span><strong> Client VS Ressource 💻</strong></span></h4>

# %% [markdown]
# Assez souvent dans la documentation, vous verrez `s3 = session.client("s3")` au lieu de `s3 = session.resource("s3")`
#
# Cela se produit parce qu'il y a une légère différence entre les deux fonctions. Voici une courte explication :
#
# - **Ressource** : API de haut niveau plus facile à utiliser mais qui ne couvrira pas 100 % de ce que vous pouvez faire avec Boto3.
# - **Client** : API de bas niveau qui couvrira 100% de ce que vous pouvez faire avec Boto3, cependant plus difficile à utiliser.
#
# Si vous souhaitez en savoir plus, consultez certainement cette [réponse géniale sur StackOverflow](https://stackoverflow.com/questions/42809096/difference-in-boto3-between-resource-client-and-session).

# %% [markdown]
# <h4 style="text-align: left; color:#20a08d; font-size: 25px"><span><strong> Resources 📚</strong></span></h4>
#
# - [Boto3 Documentation](https://boto3.amazonaws.com/v1/documentation/api/latest/guide/quickstart.html)
# - [Difference in boto3 between resource, client, and session](https://stackoverflow.com/questions/42809096/difference-in-boto3-between-resource-client-and-session)
# - [What is the difference between SDK & API](https://nordicapis.com/what-is-the-difference-between-an-api-and-an-sdk/)
